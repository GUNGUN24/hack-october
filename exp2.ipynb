# %%
import matplotlib.pyplot as plt

# %%
#sactterplot
x=[11,23,2,5,37,44,33,21,51,10]
y=[35,47,57,68,75,21,15,33,5,29]
plt.scatter(x,y,color="red",marker="*",s=80, edgecolor="blue",linewidth=2, alpha=0.5)
plt.xlabel("Label X")
plt.ylabel("Label Y")
plt.title("Scatter plot")
plt.show()
